# %%
import os
from os.path import join as opj
from glob import glob as glob
import pandas as pd
import numpy as np
from collections import Counter

# %%
root_path = "/Users/abeukers/wd/coffeworld_exp/csw_k"
timeline_fpaths = glob(opj(root_path,"stim&timeline","timeline*"))
slider_fpaths = glob(opj(root_path,"sliderdata","DATACSW*"))

timeline_fpaths.sort()
slider_fpaths.sort()

# sid = os.path.split(data_fpath)[-1].split('-')[-1].split('.')[0]
save_df_fpath = opj(root_path,'dataframes','global_df.csv')

# %% [markdown]
# ## timeline and slider data -> DF

# %%
timeline_fpath = timeline_fpaths[1]
timelines = []
  
for timeline_fpath in timeline_fpaths:
  with open(timeline_fpath) as f:
    timeline = f.read().split(',')[:-1]
  timelines.extend(timeline)

# timelines concatenated and with a global index
global_timeline = [j+"_"+str(i) for i,j in enumerate(timelines)]
global_timeline[:20]
# Out:
# ['s_0_BEGIN_0',
#  'q_1_BEGINWalktoback_BEGINWalktofront_60_Default_10_1',
#  's_2_Walktoback_2',
#  'q_3_WalktobackStepinfront_WalktobackSayexcuseme_40_Default_10_3',
#  's_4_Stepinfront_4',
#  'q_5_StepinfrontIgnore_StepinfrontIgnore_100_Alter_01_5',
#  's_6_Ignore_6',
#  'q_7_IgnoreXstare_IgnoreXstare_100_Permute_01_7',
#  's_8_Xstare_8',
#  'q_9_XstareDessertcrumble_XstareCreamsplash_50_Default_10_9',
#  's_10_Dessertcrumble_10',
#  'q_11_DessertcrumbleCallpoliceman_DessertcrumbleCallpoliceman_100_Alter_01_11',
#  's_12_Callpoliceman_12',
#  'q_13_CallpolicemanHatecoffee_CallpolicemanHatecoffee_100_Permute_01_13',
#  's_14_Hatecoffee_14',
#  'q_15_HatecoffeeEND_HatecoffeeEND_100_Alter_01_15',
#  's_16_END_16',
#  's_17_BEGIN_17',
#  'q_18_BEGINWalktofront_BEGINWalktoback_40_Default_10_18',
#  's_19_Walktofront_19']

# %%
# read timeline
state_dicts = [] # list of dicts
f = lambda x: x.split('_')
story_pass = -1
for _st in map(f,timelines):
  state_dict = {}
  state_dict['state_id'] = _st[-1]
  if _st[0] == 'q':
    state_dict['s_or_q'] = 'q'
    state_dict['state'] = state
    state_dict['edge'] = _st[2]
    state_dict['altedge'] = _st[3]
    state_dict['objective_pr'] = float(_st[4])
    state_dict['qtype'] = _st[5]
    # left or right correct response
    if _st[6] == '10':
      state_dict['slider_true_right'] = True
    elif _st[6] == '01':
      state_dict['slider_true_right'] = False
  if _st[0] == 's':
    state_dict['s_or_q'] = 's'
    state = _st[2]
    state_dict['state'] = state
    if _st[2] == 'BEGIN': story_pass += 1
  state_dict['story_pass'] = story_pass
  state_dicts.append(state_dict)

# assemble dataframe
timeline_df = pd.DataFrame(
  state_dicts,columns=['story_pass','s_or_q', 'state', 'qtype',
    'edge','altedge','slider_true_right','objective_pr']
)

# %%
timeline_df['']
# Out:
#       story_pass s_or_q           state    qtype                         edge  \
# 0              0      s           BEGIN      NaN                          NaN
# 1              0      q           BEGIN  Default              BEGINWalktoback
# 2              0      s      Walktoback      NaN                          NaN
# 3              0      q      Walktoback  Default        WalktobackStepinfront
# 4              0      s     Stepinfront      NaN                          NaN
# 5              0      q     Stepinfront    Alter            StepinfrontIgnore
# 6              0      s          Ignore      NaN                          NaN
# 7              0      q          Ignore  Permute                 IgnoreXstare
# 8              0      s          Xstare      NaN                          NaN
# 9              0      q          Xstare  Default         XstareDessertcrumble
# 10             0      s  Dessertcrumble      NaN                          NaN
# 11             0      q  Dessertcrumble    Alter  DessertcrumbleCallpoliceman
# 12             0      s   Callpoliceman      NaN                          NaN
# 13             0      q   Callpoliceman  Permute      CallpolicemanHatecoffee
# 14             0      s      Hatecoffee      NaN                          NaN
# 15             0      q      Hatecoffee    Alter                HatecoffeeEND
# 16             0      s             END      NaN                          NaN
# 17             1      s           BEGIN      NaN                          NaN
# 18             1      q           BEGIN  Default             BEGINWalktofront
# 19             1      s     Walktofront      NaN                          NaN
# 20             1      q     Walktofront  Default       WalktofrontStepinfront
# 21             1      s     Stepinfront      NaN                          NaN
# 22             1      q     Stepinfront    Alter            StepinfrontIgnore
# 23             1      s          Ignore      NaN                          NaN
# 24             1      q          Ignore  Default                 IgnoreXstare
# 25             1      s          Xstare      NaN                          NaN
# 26             1      q          Xstare  Default         XstareDessertcrumble
# 27             1      s  Dessertcrumble      NaN                          NaN
# 28             1      q  Dessertcrumble    Alter  DessertcrumbleCallpoliceman
# 29             1      s   Callpoliceman      NaN                          NaN
# ...          ...    ...             ...      ...                          ...
# 2410         148      s      Walktoback      NaN                          NaN
# 2411         148      q      Walktoback  Permute        WalktobackStepinfront
# 2412         148      s     Stepinfront      NaN                          NaN
# 2413         148      s          Ignore      NaN                          NaN
# 2414         148      q          Ignore  Permute                 IgnoreXstare
# 2415         148      s          Xstare      NaN                          NaN
# 2416         148      q          Xstare  Permute         XstareDessertcrumble
# 2417         148      s  Dessertcrumble      NaN                          NaN
# 2418         148      q  Dessertcrumble  Default  DessertcrumbleBaristaorders
# 2419         148      s   Baristaorders      NaN                          NaN
# 2420         148      q   Baristaorders  Default      BaristaordersHatecoffee
# 2421         148      s      Hatecoffee      NaN                          NaN
# 2422         148      q      Hatecoffee    Alter                HatecoffeeEND
# 2423         148      s             END      NaN                          NaN
# 2424         149      s           BEGIN      NaN                          NaN
# 2425         149      q           BEGIN  Default             BEGINWalktofront
# 2426         149      s     Walktofront      NaN                          NaN
# 2427         149      q     Walktofront  Default       WalktofrontSayexcuseme
# 2428         149      s     Sayexcuseme      NaN                          NaN
# 2429         149      q     Sayexcuseme  Permute     SayexcusemeSubjectstares
# 2430         149      s   Subjectstares      NaN                          NaN
# 2431         149      q   Subjectstares    Alter   SubjectstaresTurntobarista
# 2432         149      s   Turntobarista      NaN                          NaN
# 2433         149      q   Turntobarista  Permute  TurntobaristaDessertcrumble
# 2434         149      s  Dessertcrumble      NaN                          NaN
# 2435         149      s   Baristaorders      NaN                          NaN
# 2436         149      q   Baristaorders  Permute       BaristaordersLovejuice
# 2437         149      s       Lovejuice      NaN                          NaN
# 2438         149      q       Lovejuice    Alter                 LovejuiceEND
# 2439         149      s             END      NaN                          NaN
#
#                           altedge slider_true_right  objective_pr
# 0                             NaN               NaN           NaN
# 1                BEGINWalktofront              True          60.0
# 2                             NaN               NaN           NaN
# 3           WalktobackSayexcuseme              True          40.0
# 4                             NaN               NaN           NaN
# 5               StepinfrontIgnore             False         100.0
# 6                             NaN               NaN           NaN
# 7                    IgnoreXstare             False         100.0
# 8                             NaN               NaN           NaN
# 9               XstareCreamsplash              True          50.0
# 10                            NaN               NaN           NaN
# 11    DessertcrumbleCallpoliceman             False         100.0
# 12                            NaN               NaN           NaN
# 13        CallpolicemanHatecoffee             False         100.0
# 14                            NaN               NaN           NaN
# 15                  HatecoffeeEND             False         100.0
# 16                            NaN               NaN           NaN
# 17                            NaN               NaN           NaN
# 18                BEGINWalktoback              True          40.0
# 19                            NaN               NaN           NaN
# 20         WalktofrontSayexcuseme             False          50.0
# 21                            NaN               NaN           NaN
# 22              StepinfrontIgnore             False         100.0
# 23                            NaN               NaN           NaN
# 24            IgnoreTurntobarista             False          66.0
# 25                            NaN               NaN           NaN
# 26              XstareCreamsplash              True          50.0
# 27                            NaN               NaN           NaN
# 28    DessertcrumbleCallpoliceman             False         100.0
# 29                            NaN               NaN           NaN
# ...                           ...               ...           ...
# 2410                          NaN               NaN           NaN
# 2411        WalktobackStepinfront              True         100.0
# 2412                          NaN               NaN           NaN
# 2413                          NaN               NaN           NaN
# 2414                 IgnoreXstare             False         100.0
# 2415                          NaN               NaN           NaN
# 2416         XstareDessertcrumble             False         100.0
# 2417                          NaN               NaN           NaN
# 2418  DessertcrumbleCallpoliceman             False          90.0
# 2419                          NaN               NaN           NaN
# 2420       BaristaordersLovejuice              True          30.0
# 2421                          NaN               NaN           NaN
# 2422                HatecoffeeEND             False         100.0
# 2423                          NaN               NaN           NaN
# 2424                          NaN               NaN           NaN
# 2425              BEGINWalktoback              True          40.0
# 2426                          NaN               NaN           NaN
# 2427       WalktofrontStepinfront             False          50.0
# 2428                          NaN               NaN           NaN
# 2429     SayexcusemeSubjectstares              True         100.0
# 2430                          NaN               NaN           NaN
# 2431   SubjectstaresTurntobarista             False         100.0
# 2432                          NaN               NaN           NaN
# 2433  TurntobaristaDessertcrumble              True         100.0
# 2434                          NaN               NaN           NaN
# 2435                          NaN               NaN           NaN
# 2436       BaristaordersLovejuice              True         100.0
# 2437                          NaN               NaN           NaN
# 2438                 LovejuiceEND              True         100.0
# 2439                          NaN               NaN           NaN
#
# [2440 rows x 8 columns]

# %%
slider_df = pd.DataFrame(columns=('trial_type','response'))

# slider data
idx = -1
for slider_fpath in slider_fpaths:
  print(slider_fpath)
  _df = pd.DataFrame.from_csv(
    slider_fpath,index_col=3)[['trial_type','response']]
  slider_df = slider_df.append(_df)

slider_df.index = range(len(slider_df))

df = slider_df.merge(timeline_df, left_index=True, right_index=True)
# Out:
# /Users/abeukers/wd/coffeworld_exp/csw_k/sliderdata/DATACSW-0.csv
# /Users/abeukers/wd/coffeworld_exp/csw_k/sliderdata/DATACSW-1.csv
# /Users/abeukers/wd/coffeworld_exp/csw_k/sliderdata/DATACSW-2.csv
# /Users/abeukers/wd/coffeworld_exp/csw_k/sliderdata/DATACSW-3.csv
# /Users/abeukers/wd/coffeworld_exp/csw_k/sliderdata/DATACSW-4.csv

# %% [markdown]
# ## experienced probabilities

# %%
ecount = Counter({e:0 for e in set(df.edge)})

for i in range(len(df)):
  
  e = df.iloc[i]['edge']
  ae = df.iloc[i]['altedge']
  df.set_value(i,'edge_count',ecount[e])
  df.set_value(i,'altedge_count',ecount[ae])

  # calculate normalized experienced probability   
  if ecount[e]+ecount[ae]==0:
    experienced_edge = 0
    experienced_altedge = 0
  else:
    experienced_edge = ecount[e] / (ecount[e]+ecount[ae])
    experienced_altedge = ecount[ae] / (ecount[e]+ecount[ae])
    
  df.set_value(i,'ex_pr_edge',experienced_edge*100)
  df.set_value(i,'ex_pr_altedge',experienced_altedge*100)
    
  # edge count at every given trial
  ecount[e] += 1

# df[df['s_or_q'] == 'q']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4b25f846f14e> in <module>()
# ----> 1 ecount = Counter({e:0 for e in set(df.edge)})
#       2
#       3 for i in range(len(df)):
#       4
#       5   e = df.iloc[i]['edge']
#
# NameError: name 'Counter' is not defined

# %% [markdown]
# ## correct slider position

# %% [markdown]
# resp_objective
# resp_experienced_edge
# resp_experienced_altedge

# %%
for i in range(len(df)):
  if pd.isnull(df.iloc[i]['slider_true_right']):
    continue
  elif df.iloc[i]['slider_true_right']:
    resp_obj = df.iloc[i]['objective_pr']
    resp_ex_pr_edge = df.iloc[i]['ex_pr_edge']
    resp_ex_pr_altedge = df.iloc[i]['ex_pr_altedge']
  else: # left response is correct
    resp_obj = 100 - df.iloc[i]['objective_pr']
    resp_ex_pr_edge = 100 - df.iloc[i]['ex_pr_edge']
    resp_ex_pr_altedge = 100 - df.iloc[i]['ex_pr_altedge']
    
  df.set_value(i,'resp_objective',resp_obj)
  df.set_value(i,'resp_ex_pr_edge',resp_ex_pr_edge)
  df.set_value(i,'resp_ex_pr_altedge',resp_ex_pr_altedge)

# %% [markdown]
# ## binary response

# %%
df['response_right'] = df['response'] > 0.5
df['response_objective_right'] = df['resp_objective'] > 0.5
df['response_experienced_right'] = df['resp_ex_pr_edge'] > 0.5

# %%
df['correct'] = df['response_right'] == df['response_objective_right']

# %% [markdown]
# ## save df

# %%
df.to_csv(save_df_fpath)
